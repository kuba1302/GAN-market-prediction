# %%
import os 
import pandas as pd 
import matplotlib.pyplot as plt 
from pathlib import Path
import json 

# %load_ext autoreload
# %autoreload 2

from utils.plot import (plot_all_prices, 
                        plot_bb, 
                        plot_multiple_lines, 
                        plot_macd)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (30, 10)


stock_dir_path = str(Path(os.path.abspath('')) / 'data/stock_data/')
tickers_path = str(Path(os.path.abspath('')) / 'data/stocksTickers.json')
reddit_path = str(Path(os.path.abspath('')) / 'data/reddit_data/')
game_names_1_path = str(Path(os.path.abspath('')) / 'data/game_names.json')
game_names_2_path = str(Path(os.path.abspath('')) / 'data/game_names_2.json')

def load_all_stocks_data(stock_path=stock_dir_path):
    data_dict = {}
    for filename in os.listdir(stock_path): 
        try: 
            data_dict[filename.split('.')[0]] = pd.read_csv(str(Path(stock_path) / filename)).drop(columns='Unnamed: 0')

        except KeyError:
            data_dict[filename.split('.')[0]] = pd.read_csv(str(Path(stock_path) / filename))
            
    return data_dict

data_dict = load_all_stocks_data() 
main_stock_names = ['electronic arts', 'blizzard', 'take-two', 'ubisoft']
main_stock_dict = {key: data_dict[key] for key in main_stock_names }
ea = data_dict['electronic arts']
blizzard = data_dict['blizzard']
take_two = data_dict['take-two']
ubisoft = data_dict['ubisoft']

with open(game_names_1_path) as game_names_file_1:
    game_names_1 = json.load(game_names_file_1)

with open(game_names_2_path) as game_names_file_2:
    game_names_2 = json.load(game_names_file_2)

reddit_dict = load_all_stocks_data(reddit_path)
    
df = pd.read_csv(str(Path(os.path.abspath('')) / 'data/blizzard.csv')).drop(columns='Unnamed: 0')

# %% [markdown]
# # Gaming industry stock price prediction using BERT and GAN
# # 1. Stock Data
# ## 1.1 Origin of the data
# Data comes from yahoo finance python API
#
# ## 1.2 Chosen companies:
#  ### 1. Electronic Arts
#  ### 2. UBISOFT
#  ### 3. TAKE-TWO
#  ### 4. BLIZZARD <br>

# %% [markdown]
# ## 1.3 Selected time period:
# ### 2018-12-11 - 2021-12-10

# %% [markdown]
# ## 1.4 Stock data exploration

# %%
blizzard
# Out:
#            Date       Open       High        Low      Close    Volume  \
# 0    2018-12-11  47.637469  47.921902  46.803791  47.274574  12474126
# 1    2018-12-12  48.108254  49.255792  47.490349  47.519775  11453591
# 2    2018-12-13  47.814015  48.314221  46.804772  47.578621   7755190
# 3    2018-12-14  46.558591  47.519775  46.068191  46.833214   7161356
# 4    2018-12-17  46.686096  47.490351  45.744528  46.176083  10064952
# ..          ...        ...        ...        ...        ...       ...
# 752  2021-12-06  57.529999  58.450001  57.240002  58.090000   9408963
# 753  2021-12-07  58.919998  59.270000  58.282001  58.770000  11553517
# 754  2021-12-08  58.779999  60.009998  58.029999  59.270000   9785536
# 755  2021-12-09  58.595001  59.810001  58.520000  59.070000   8402308
# 756  2021-12-10  59.160000  59.410000  57.470001  58.599998   9884081
#
#      Dividends  Stock Splits
# 0          0.0             0
# 1          0.0             0
# 2          0.0             0
# 3          0.0             0
# 4          0.0             0
# ..         ...           ...
# 752        0.0             0
# 753        0.0             0
# 754        0.0             0
# 755        0.0             0
# 756        0.0             0
#
# [757 rows x 8 columns]

# %%
plot_all_prices(main_stock_dict, 'Date', 'Close', [30, 10])

# %% [markdown]
# ## 1.5 Chosen ETF-s
#   ### 1. Global X Video Games & Esports ETF
#   ### 2. VanEck Vectors Video Gaming and eSports
#   ### 3. Roundhill BITKRAFT Esports & Digital Entertainment ETF

# %% [markdown]
# # 2 Technical analysis
# ## 2.1 Simple moving averages

# %%
plot_multiple_lines(
    'Simple moving averages example', 
    df['Close'], 
    [
        (df['sma_5'], 'SMA with 5 days window', 'y'), 
        (df['sma_20'], 'SMA with 20 days window', 'r'), 
        (df['sma_50'], 'MA with 50 days window', 'b')
    ]
)

# %% [markdown]
# ## 2.2 Exponential moving averages

# %%
plot_multiple_lines(
    'Exponential moving averages example', 
    df['Close'], 
    [
        (df['ema_5'], 'EMA with 5 days window', 'y'), 
        (df['ema_20'], 'EMA with 20 days window', 'r'), 
        (df['ema_50'], 'EMA with 50 days window', 'b')
    ]
)

# %% [markdown]
# ## 2.3 Weighted moving averages

# %%
plot_multiple_lines(
    'Weighted moving averages example', 
    df['Close'], 
    [
        (df['wma_5'], 'WMA with 5 days window', 'y'), 
        (df['wma_20'], 'WMA with 20 days window', 'r'), 
        (df['wma_50'], 'WMA with 50 days window', 'b')
    ]
)

# %% [markdown]
# ## 2.4 Bollinger Bands

# %%
plot_bb(
    df['Close'], 
    df['bb_20_up'], 
    df['bb_20_down']
)

# %% [markdown]
# ## 2.5 Moving average convergence/divergence (MACD)

# %%
plot_macd(
    df['macd'], 
    df['signal']
)
plt.plot(df['Close'])
plt.show()

# %% [markdown]
# # 3 Choosing keywords for data scraping
#
# ## 3.1 First approach - Scraping game names of chosen companies from wikipedia

# %%
game_names_1
# Out:
# {'ATVI': ['Blizzard',
#   'Starcraft',
#   'Warcraft',
#   'Overwatch',
#   'Diablo',
#   'World of Warcraft',
#   'Hearthstone',
#   'Heroes of the Storm'],
#  'UBSFY': ["Assassin's Creed Chronicles: China",
#   'NCIS',
#   "Tom Clancy's H.A.W.X 2",
#   'Rayman Legends: Definitive Edition',
#   'Rayman Mini',
#   'Driver: San Francisco',
#   "Assassin's Creed: Revelations",
#   'Anno 2070',
#   'Prince of Persia Classic',
#   'Imagine: Fashion Life',
#   'The Hollywood Squares',
#   'The Black Eyed Peas Experience',
#   'Red Steel 2',
#   'Rabbids Big Bang',
#   'From Dust',
#   'Rabbids Crazy Rush',
#   'Rabbids Invasion: The Interactive TV Show',
#   'Jeopardy!',
#   'Rocksmith: All-new 2014 Edition - Remastered',
#   'Far Cry New Dawn',
#   'Flashback',
#   'Battle of Giants: Dinosaurs - Fight for Survival',
#   'Funky Barn 3D',
#   'The Smurfs 2',
#   "Gold's Gym Dance Workout",
#   'Trials Frontier',
#   'Mario + Rabbids Kingdom Battle',
#   'Silent Hunter 5: Battle of the Atlantic',
#   'Hungry Shark: World',
#   'Just Dance 2',
#   'Spartacus Legends',
#   'Prince of Persia',
#   'Puzzler World 2011',
#   'Fighters Uncaged',
#   'Prince of Persia: The Shadow and the Flame',
#   'Trials Fusion',
#   'Castle & Co',
#   'Risk',
#   'Rabbids: Coding!',
#   'Just Dance: Disney Party',
#   'Just Dance: Disney Party 2',
#   'Rayman Adventures',
#   "Assassin's Creed Origins",
#   'Call of Juarez: Gunslinger',
#   'Care Bears: Belly Match',
#   'Just Dance 2018',
#   "Assassin's Creed Odyssey",
#   "Tom Clancy's Ghost Recon Breakpoint",
#   'TrackMania 2: Valley',
#   'City of Love: Paris',
#   'Far Cry 4: Arena Master',
#   "Assassin's Creed II: Discovery",
#   "Tom Clancy's Splinter Cell: Chaos Theory HD",
#   'Watch Dogs',
#   'Just Dance 2019',
#   'Sleepover Party',
#   'Might & Magic: Clash of Heroes',
#   'Valiant Hearts: The Great War',
#   'Horse Haven: World Adventures',
#   'South Park: The Fractured But Whole',
#   "Tom Clancy's Ghost Recon: Shadow Wars",
#   'The Crew',
#   "Tom Clancy's Ghost Recon: Future Soldier",
#   'Shoot Many Robots',
#   'MotionSports',
#   'ESPN Sports Connection',
#   'Rocksmith: All-new 2014 Edition',
#   'Petz Countryside',
#   "Assassin's Creed Chronicles: India",
#   'Driver: Renegade',
#   'Self-Defense Training Camp',
#   'TrackMania 2: Canyon',
#   'Might & Magic: Duel of Champions',
#   'Fit in Six',
#   'Petz: Dogz Family',
#   'NCIS 3D',
#   'Racquet Sports',
#   'Toy Soldiers: War Chest',
#   'Rayman Legends',
#   'Scrabble',
#   'Nutty Fluffies Rollercoaster',
#   "Assassin's Creed Pirates",
#   'Monopoly Deal',
#   'IL-2 Sturmovik: Cliffs of Dover',
#   'I Am Alive',
#   'Rayman',
#   'Family Feud: 2012 Edition',
#   "Discovery Tour: Assassin's Creed - Ancient Greece",
#   'Zombi',
#   'ZombiU',
#   'Sports Collection: 15 Sports to Master',
#   'Monopoly Plus',
#   'Trivial Pursuit Live!',
#   'Werewolves Within',
#   'PowerUp Heroes',
#   "Assassin's Creed: The Ezio Collection",
#   'The Mighty Quest for Epic Loot',
#   'Just Dance Kids 2014',
#   'We Dare',
#   'Driver: Speedboat Paradise',
#   "Tom Clancy's Splinter Cell HD",
#   'Poptropica Adventures',
#   "Tom Clancy's Ghost Recon Wildlands",
#   "Tom Clancy's Ghost Recon Phantoms",
#   "Little Raiders: Robin's Revenge",
#   'Anno Online',
#   'Prince of Persia: The Sands of Time HD',
#   'Monkey King Escape',
#   'Babel Rising 3D',
#   'The Hip Hop Dance Experience',
#   'The Smurfs & Co: Spellbound',
#   'Trials of the Blood Dragon',
#   'Voodoo Dice',
#   'Scott Pilgrim vs. the World: The Game',
#   'Prince of Persia: The Two Thrones HD',
#   'Combat of Giants: Dinosaurs 3D',
#   'Anno: Build an Empire',
#   'Boggle',
#   "Discovery Tour: Assassin's Creed - Ancient Egypt",
#   "Assassin's Creed: Rebellion",
#   'Champions of Anteria',
#   'Imagine: Gymnast',
#   'Battle of Giants: Mutant Insects',
#   'Prince of Persia: The Forgotten Sands',
#   'Rabbids Land',
#   'Just Dance 2016',
#   "Assassin's Creed Unity",
#   'TrackMania 2: Lagoon',
#   "Assassin's Creed: Liberation HD",
#   'Petz Fantasy 3D',
#   'Just Dance 2014',
#   'Splinter Cell: Blacklist - Spider-Bot',
#   "James Noir's Hollywood Crimes",
#   'The Settlers Online',
#   'Babel Rising',
#   'Sports Party',
#   'Just Dance 2015',
#   'Dance on Broadway',
#   'Galaxy Racers',
#   'Puzzler World 2012',
#   "Assassin's Creed IV: Black Flag",
#   'The Smurfs & Co',
#   'Rayman Origins',
#   'For Honor',
#   "Tom Clancy's Ghost Recon Predator",
#   'CSI: Hidden Crimes',
#   'Trials Rising',
#   'Grow Home',
#   'CSI: Fatal Conspiracy',
#   'Just Dance 2020',
#   'Just Dance 3',
#   'Puppies 3D',
#   'Horses 3D',
#   'Shaun White Skateboarding',
#   "Assassin's Creed: Recollection",
#   'Family Feud: Decades',
#   'The $1,000,000 Pyramid',
#   'Child of Eden',
#   'South Park: The Stick of Truth',
#   'Just Dance Now',
#   'Face Up: The Selfie Game',
#   'Might & Magic: Heroes Online',
#   'Star Trek: Bridge Crew',
#   'Grow Up',
#   'Petz: Catz Family',
#   'Anno 1800',
#   "Assassin's Creed III: Liberation",
#   'Raving Rabbids: Alive & Kicking',
#   "Tom Clancy's The Division 2",
#   'Arthur and the Revenge of Maltazard',
#   'Rayman Fiesta Run',
#   'The Avengers: Battle for Earth',
#   'Rabbids Rumble',
#   "Assassin's Creed Chronicles: Russia",
#   'The Crew 2',
#   "Assassin's Creed III Remastered",
#   'R.U.S.E.',
#   'Brawlhalla',
#   'Outland',
#   'Ode',
#   'Just Dance 4',
#   'Imagine: Babyz',
#   'TrackMania Turbo',
#   'Imagine: Fashion Designer',
#   'Just Sing',
#   'Monopoly',
#   'Trials Evolution',
#   "Assassin's Creed: Memories",
#   'Cubic Ninja',
#   'The Price is Right: Decades',
#   'Zoo Mania 3D',
#   'MotoHeroz',
#   'Rocksmith',
#   'Legendary Fishing',
#   "Tom Clancy's Splinter Cell: Pandora Tomorrow HD",
#   'Growtopia',
#   'Rayman 3D',
#   'Rabbids: Travel in Time 3D',
#   'Watch Dogs 2',
#   'Atomega',
#   'The Smurfs Dance Party',
#   'The Expendables 2: Videogame',
#   'ZeitÂ²',
#   'Far Cry 3',
#   'Michael Jackson: The Experience',
#   'The Smurfs',
#   "Tom Clancy's Splinter Cell Classic Trilogy HD",
#   'Just Dance Kids 2',
#   'Shape Up',
#   'Tetris Ultimate',
#   'Anno 2205: Asteroid Miner',
#   'The Smurfs: Epic Run',
#   'Rock Gods: Tap Tour',
#   'NCIS: Hidden Crimes',
#   'Eagle Flight',
#   'Wheel of Fortune',
#   'Just Dance 2017',
#   'Child of Light',
#   'No More Heroes 2: Desperate Struggle',
#   'Sandstorm: Pirate Wars',
#   'Far Cry 3: Classic Edition',
#   'Your Shape: Fitness Evolved 2012',
#   'Far Cry 4: Arcade Poker',
#   'Raving Rabbids: Travel in Time',
#   'Starlink: Battle for Atlas',
#   'Shape Up: Battle Run',
#   'ShootMania Storm',
#   'Hungry Dragon',
#   "Assassin's Creed Rogue",
#   'Child of Light: Ultimate Edition',
#   'Battle of Giants: Mutant Insects - Revenge',
#   'Boot Camp Academy',
#   'Puzzler Mind Gym 3D',
#   'OK! Puzzle Stars',
#   "Tom Clancy's The Division",
#   'Might & Magic Heroes: Era of Chaos',
#   "Tom Clancy's Splinter Cell: Blacklist",
#   'ABBA: You Can Dance',
#   'South Park: Phone Destroyer',
#   "Tom Clancy's Splinter Cell: Conviction",
#   'The Adventures of Tintin: The Secret of the Unicorn',
#   'Might & Magic Heroes VI',
#   'Dungeon Hunter: Alliance',
#   'Fighter Within',
#   'Trials Evolution: Gold Edition',
#   'Just Dance: Best Of',
#   'My Chinese Coach',
#   'Asphalt: Injection',
#   'The Smurfs 3D',
#   'Monster 4x4 3D',
#   'CSI: Unsolved!',
#   "Assassin's Creed III",
#   "Assassin's Creed Identity",
#   'Gravity Falls: Legend of the Gnome Gemulets',
#   'Far Cry 3: Blood Dragon',
#   'Beyond Good & Evil HD',
#   "Tom Clancy's Ghost Recon",
#   "Assassin's Creed Rogue Remastered",
#   'Might & Magic X: Legacy',
#   'Far Cry 5',
#   'Battle of Giants: Dinosaurs Strike',
#   "Assassin's Creed II",
#   "Tom Clancy's Rainbow Six Siege",
#   "Tom Clancy's EndWar Online",
#   'Far Cry Primal',
#   'Rayman 3 HD',
#   "Assassin's Creed: The Rebel Collection",
#   'Anno 2205',
#   'Lumines: Electronic Symphony',
#   'Bloody Good Time',
#   'MotionSports Adrenaline',
#   "Tom Clancy's Splinter Cell 3D",
#   'Battleship',
#   "Assassin's Creed: Brotherhood",
#   'Far Cry Classic',
#   'Petz Hamsterz Family',
#   'Cloudberry Kingdom',
#   'Rayman Jungle Run',
#   'Uno',
#   'Panzer General Online',
#   'Michael Jackson: The Experience 3D',
#   'The Settlers: History Edition',
#   'Transference',
#   'Your Shape: Fitness Evolved 2013',
#   'Call of Juarez: The Cartel',
#   'Risk: Urban Assault',
#   'Far Cry 4',
#   "Assassin's Creed Syndicate",
#   'Space Junkies',
#   'TrackMania 2: Stadium',
#   'Steep',
#   'Asphalt 6: Adrenaline',
#   'The Settlers 7: Paths to a Kingdom',
#   'Prince of Persia: Warrior Within HD',
#   'Rabbids Appisodes',
#   'Petz Beach',
#   'Just Dance Kids',
#   'Mad Riders',
#   "Assassin's Creed Valhalla",
#   'Riders Republic',
#   'Beyond Good and Evil 2',
#   "Assassin's Creed Infinity",
#   'Just Dance 2022',
#   'Avatar: Frontiers of Pandora',
#   'AGOS: A Game of Space',
#   'Might & Magic: Chess Royale',
#   'Scott Pilgrim vs. The World: The Game - Complete Edition',
#   'Monopoly Madness',
#   'Mario + Rabbids Sparks of Hope',
#   'The Settlers',
#   "Assassin's Creed",
#   "Tom Clancy's XDefiant",
#   "Tom Clancy's The Division 2",
#   "Tom Clancy's The Division Heartland",
#   'Far Cry 6',
#   'The Crew 2',
#   'Immortals Fenyx Rising',
#   "Tom Clancy's Rainbow Six Siege",
#   'Rabbids: Coding!',
#   'Family Feud',
#   'Rocksmith+',
#   'Brawlhalla',
#   'Watch Dogs: Legion',
#   'Rabbids Wild Race',
#   'Hyper Scape',
#   "Tom Clancy's Rainbow Six Extraction",
#   'Prince of Persia: The Sands of Time Remake',
#   "Tom Clancy's Ghost Recon Frontline",
#   'Discovery Tour: Viking Age',
#   'Roller Champions',
#   "Tom Clancy's Splinter Cell",
#   'Untitled Star Wars game',
#   "Tom Clancy's Elite Squad",
#   'TrackMania',
#   'Skull & Bones',
#   'Just Dance 2021',
#   'Idle Restaurant Tycoon'],
#  'EA': ['SimCity',
#   'NHL 18',
#   'The Sims Mobile',
#   'Iron Force 2',
#   'Rocket Arena',
#   'Battlefield 2042',
#   'Star Wars Battlefront',
#   'NCAA Football 11',
#   'FIFA 21',
#   'Bejeweled Classic HD',
#   'Ultima Forever: Quest for the Avatar',
#   'Dungeon Keeper Mobile',
#   'The Simpsons: Tapped Out',
#   'FIFA 12',
#   'Madden NFL 15',
#   'Unravel',
#   'EA Sports MMA',
#   'Mass Effect: Andromeda',
#   'Risk: Factions',
#   'NBA Jam',
#   'The Sims 4: Get Famous',
#   'The Sims 3: Showtime',
#   'Ultima Underworld: The Stygian Abyss and Labyrinth of Worlds',
#   'Warp',
#   'UFC Mobile',
#   'Bejeweled Blitz',
#   'Battlefield Hardline',
#   'Star Wars: Squadrons',
#   'Tiger Woods PGA Tour 14',
#   'High Caliber Hunting',
#   'Shank 2',
#   'Crysis 3',
#   'Reckless Racing',
#   'The Sims 4: Cats & Dogs',
#   '2010 FIFA World Cup South Africa',
#   'FIFA Online 3',
#   'Command & Conquer: Rivals',
#   'The Sims 4: Parenthood',
#   'The Sims 4: Spa Day',
#   'The Sims 3: Generations',
#   'EA Sports Active 2',
#   'EA Sports UFC 2',
#   'Command & Conquer 4: Tiberian Twilight',
#   'NHL 21',
#   'Darkspore',
#   'Iron Force',
#   'The Sims 3: University Life',
#   'The Sims 4: Star Wars: Journey to Batuu',
#   'NHL 13',
#   'WarFriends',
#   'Command & Conquer Remastered Collection',
#   'The Sims 4: StrangerVille',
#   'APB: All Points Bulletin',
#   'The Sims Medieval: Pirates and Nobles',
#   'NBA Live 16',
#   'Peggle Blast',
#   'The Secret World',
#   'Plants vs. Zombies',
#   'Dead Space 3',
#   'Pogo Games',
#   'Battlefield 4',
#   'The Secret Life of Pets Unleashed',
#   'The Sims 4: Eco Lifestyle',
#   'Dragon Age 4',
#   'RISK',
#   'Heroes Lore III',
#   "Dragon's Lair[a]",
#   'SimCity 4 Deluxe Edition',
#   'Dead Space',
#   'Rock Band 3',
#   'Skate It',
#   'Mass Effect 3',
#   'Spore Creatures',
#   'UEFA Euro 2012',
#   'NCAA Football 13',
#   'NBA Live Mobile',
#   'Skate 3',
#   "Mirror's Edge Catalyst",
#   'Dragon Age: Origins â\x80\x93 Awakening',
#   'Pet Society Vacation',
#   'Madden NFL 22',
#   'Grand Slam Tennis 2',
#   'A Way Out',
#   'The Sims 4: Dine Out',
#   'Knockout City',
#   'The Sims 3: Into the Future',
#   'Plants vs. Zombies: Battle for Neighborville',
#   'EA Sports UFC',
#   'Monopoly Streets',
#   'FIFA 15',
#   'Untitled Battlefield mobile game',
#   'Rango',
#   'Trenches 2',
#   'Titanfall',
#   'FIFA 16',
#   'The Sims 3: Seasons',
#   'Dragon Age II',
#   'Need for Speed: Nitro-X',
#   'Titanfall 2',
#   'Spare Parts',
#   'SimCity Social',
#   'Bejeweled 2',
#   'Crysis',
#   'NHL Slapshot',
#   'World Series of Poker',
#   'Need for Speed Rivals',
#   'The Sims 4: Vampires',
#   'NCAA Football',
#   'Heroes of Dragon Age',
#   'Star Wars Battlefront II',
#   'The Sims 4: Discover University',
#   'The Sims 3: Supernatural',
#   'Create',
#   'NCAA Football 14',
#   'Need for Speed: Undercover',
#   'DeathSpank',
#   'FIFA 11',
#   'NCAA Football 12',
#   'Untitled Need for Speed game',
#   'Mass Effect Infiltrator',
#   'Madden NFL 21',
#   'Skate 4',
#   'The Sims 4: Outdoor Retreat',
#   'Anthem',
#   'Madden NFL Mobile',
#   'Fight Night Champion',
#   'Monopoly',
#   'NHL 20',
#   'Madden NFL 11',
#   'Minions Paradise',
#   'Star Wars: The Old Republic',
#   'The Sims Medieval',
#   'NHL 17',
#   'Lord of Ultima',
#   'JetSet Secrets',
#   'The Sims 4: Seasons',
#   'NHL 11',
#   'Shift 2: Unleashed',
#   'FIFA Manager 12',
#   'NFS Heat',
#   'Cause of Death',
#   'Fe',
#   'Tiger Woods PGA Tour 13',
#   'NHL 16',
#   'FIFA Manager 14',
#   'Need for Speed Payback',
#   'Clue: Secrets & Spies',
#   'Hasbro Family Game Night 3',
#   'Medal of Honor',
#   'FIFA Manager 11',
#   'Command & Conquer: Tiberium Alliances',
#   'Madden NFL 13',
#   'The Sims FreePlay',
#   'Flight Control Rocket',
#   'The Sims 4: Realm of Magic',
#   'Battlefield V',
#   'Burnout Paradise Remastered',
#   'NHL 19',
#   'Tiger Woods PGA Tour 12',
#   'Kingdoms of Amalur: Reckoning',
#   'Yogify',
#   'Madden NFL Football',
#   "Mirror's Edge",
#   'Real Racing 2',
#   'FIFA World',
#   'FIFA 18',
#   'The Sims 3: Ambitions',
#   "The Sims 3 Collector's Edition",
#   'Untitled Motive Studios game',
#   'Syndicate',
#   'Untitled Mass Effect game',
#   'Auditorium',
#   'Scrabble',
#   'NBA Elite 11',
#   '2014 FIFA World Cup Brazil',
#   'RushHeart',
#   'F1 2021',
#   'The Sims 4: Get to Work',
#   'FIFA Street',
#   'Madden NFL Overdrive',
#   'The Sims 3: Late Night',
#   'Lost in Random',
#   'Outernauts',
#   'Madden NFL 21 Mobile',
#   'The Sims 4: Snowy Escape',
#   'NBA Live 19',
#   'The Sims 4',
#   'Star Wars: Galaxy of Heroes',
#   'Madden NFL 17',
#   'Alice: Madness Returns',
#   'Madden NFL Superstars',
#   'Dead Space 2',
#   'Shank',
#   'FIFA 13',
#   'FIFA 20',
#   'Rory McIlroy PGA Tour',
#   'Surviving High School',
#   'EA Sports PGA Tour',
#   'FIFA 19',
#   'FIFA Mobile',
#   'Dragon Age: Inquisition',
#   'Burnout Crash!',
#   'The Sims 3',
#   'Real Racing 3',
#   'FIFA 17',
#   'Star Wars Jedi: Fallen Order',
#   'MySims SkyHeroes',
#   'Need for Speed: Most Wanted',
#   'Madden NFL 20',
#   'FIFA Manager 13',
#   'Madden NFL 19',
#   'NBA Live 14',
#   'SimCity: BuildIt',
#   'The Sims 4: Jungle Adventure',
#   'Fightback',
#   'Need for Speed',
#   'It Takes Two',
#   'Green Day: Rock Band',
#   'Need for Speed: Hot Pursuit',
#   'Medal of Honor: Frontline',
#   'Need for Speed: The Run',
#   'Dead Space Ignition',
#   'Sea of Solitude',
#   'EA Sports UFC 4',
#   'Battlefield Bad Company 2',
#   'Pictureka!',
#   'Plants vs. Zombies: Garden Warfare 2',
#   "Dante's Inferno",
#   'Tiger Woods PGA Tour Online',
#   'Spy Mouse',
#   'The Sims 4: Island Living',
#   'Shadows of the Damned',
#   'NHL 22',
#   'NHL Superstars',
#   'Mass Effect Legendary Edition',
#   'R-Type',
#   "Army of Two: The Devil's Cartel",
#   'Army of Two: The 40th Day',
#   'Ultimate Mortal Kombat 3',
#   "Zuma's Revenge!",
#   'Theme Park',
#   'The Sims Social',
#   'Grid Legends',
#   'EA Sports FIFA Superstars',
#   'The Sims 3: Pets',
#   'Harry Potter and the Deathly Hallows â\x80\x93 Part 2',
#   'Madden NFL 18',
#   'Plants vs. Zombies: Garden Warfare',
#   'The Sims 3 Stuff packs',
#   'Bulletstorm',
#   'Bejeweled 3',
#   'Need for Speed: World',
#   'NBA Live 15',
#   'SSX 3',
#   'Battlefield 1',
#   'EA Sports UFC 3',
#   'Hasbro Family Game Night 4: The Game Show',
#   'The Sims 4 Stuff packs',
#   'NFL Blitz',
#   "American McGee's Alice",
#   'Battle Copters',
#   'NBA Street Online 2',
#   "Plants vs. Zombies 2: It's About Time",
#   'Peggle 2',
#   'NBA Live 18',
#   'Mass Effect 2',
#   'SSX',
#   'FIFA Online 4',
#   'The Sims 4: Get Together',
#   'Plants vs. Zombies Heroes',
#   'The Sims 4: City Living',
#   'Madden NFL 16',
#   'Tetris',
#   'Crysis 2',
#   'The Sims 3: Island Paradise',
#   'Madden NFL Social',
#   'Micro Machines',
#   'Tiger Woods PGA Tour 11',
#   'Madden NFL 25',
#   'Lite-Brite',
#   'Unravel Two',
#   'Battlefield 3',
#   'Dragon Age Legends',
#   'Harry Potter and the Deathly Hallows â\x80\x93 Part 1',
#   'Dead Space: Extraction',
#   'NHL 12',
#   'Medal of Honor: Above and Beyond',
#   'Apex Legends',
#   'FIFA Online',
#   'FIFA 22',
#   'Bejeweled Stars',
#   'NBA Jam: On Fire Edition',
#   'SimCity Deluxe',
#   'DeathSpank: Thongs of Virtue',
#   'Fantasy Safari',
#   "Texas Hold'em",
#   'Rock Band Reloaded',
#   'Madden NFL 12',
#   'Need for Speed: Hot Pursuit Remastered',
#   'Medal of Honor: Warfighter',
#   'Star Wars: Rise to Power',
#   'NHL 15',
#   'Need for Speed: No Limits',
#   'Fuse',
#   'FIFA 14',
#   'EA Sports Active NFL Training Camp',
#   'Extreme Pinball',
#   'NHL 14'],
#  'TTWO': ['Major League Baseball 2K9',
#   'The Bigs 2',
#   'MyNBA 2K14',
#   'Major League Baseball 2K9: Fantasy All-Stars',
#   "Sid Meier's Starships",
#   "There's Something in the Sea",
#   'Mafia II: Definitive Edition',
#   'Borderlands 2 VR',
#   'WWE 2K20',
#   'NBA 2K11',
#   'MLB Power Pros 2008',
#   "Dora the Explorer: Dora's Big Birthday Adventure",
#   'NBA 2K19',
#   'Major League Baseball 2K7',
#   'Nickelodeon Dance 2',
#   'WWE 2K22',
#   'MLB Superstars',
#   'College Hoops 2K7',
#   "Comedy Central's Indecision Game",
#   'MLB Power Pros',
#   'Evolve',
#   'NHL 2K10',
#   'WWE SuperCard',
#   'Carnival Games: Monkey See, Monkey Do',
#   'Dora the Explorer: Dora Saves the Crystal Kingdom',
#   'Don King Boxing',
#   'NHL SuperCard 2K17',
#   'NBA 2K15',
#   'Beejumbled',
#   'Carnival Games VR',
#   'Borderlands',
#   'Borderlands 2: Ultra HD',
#   'NBA 2K MyLIFE',
#   'College Hoops 2K8',
#   'NHL 2K8',
#   'NBA 2K21',
#   'Carnival Games: Mini Golf',
#   'NBA 2KVR Experience',
#   'Evolve Stage 2',
#   'Mafia: Definitive Edition',
#   'Fantastic Four: Rise of the Silver Surfer',
#   'Mafia III: Rivals',
#   'Stronghold Legends',
#   'All-Pro Football 2K8',
#   'Close Combat: First to Fight',
#   'Nickelodeon Fit',
#   'Ni Hao, Kai-Lan: New Year Celebration',
#   'Battleborn: Free Trial',
#   'NHL SuperCard',
#   'NBA 2K14',
#   'NBA 2K6',
#   'Team Umizoomi',
#   'House Pest featuring Fiasco the Cat',
#   "Evolve: Hunter's Quest",
#   'WWE SuperCard â\x80\x93 Season 5',
#   "Sid Meier's Civilization Revolution 2 Plus",
#   'Nicktoons MLB',
#   'Baseball Blast!',
#   'Shattered Union',
#   'World Poker Tour',
#   'XCOM 2: Collection',
#   'XCOM 2',
#   "Dora & Kai-Lan's Pet Shelter",
#   'Major League Baseball 2K5',
#   'NBA 2K12',
#   'XCOM: Enemy Unknown Plus',
#   'Bubble Guppies',
#   'Top Spin 4',
#   'WWE SuperCard - Season 6',
#   'Wonder Pets! Save the Animals!',
#   'Borderlands: The Pre-Sequel! â\x80\x93 Ultra HD',
#   'NBA 2K22',
#   'Torino 2006',
#   'Go, Diego, Go! Safari Rescue',
#   'WWE 2K15',
#   'The Golf Club 2019 featuring PGA Tour',
#   'The Darkness II',
#   'NBA 2K17',
#   'WWE 2K17',
#   'MyNBA 2K19',
#   'The Bigs',
#   'Vietcong 2',
#   'Top Spin 3',
#   'NBA 2K Mobile - Season 3',
#   'NBA 2K10: Draft Combine',
#   'The Bureau: XCOM Declassified',
#   "Team Umizoomi & Dora's Fantastic Flight",
#   'NBA 2K21: Arcade Edition',
#   'Nicktoons MLB 3D',
#   'WWE SuperCard â\x80\x93 Season 3',
#   '2K Drive',
#   'PGA Tour 2K21',
#   "Sid Meier's Railroads!",
#   'NBA 2K13',
#   'Major League Baseball 2K10',
#   'Zathura',
#   'Amped 3',
#   'Ford Racing 3',
#   'Borderlands 2',
#   'Borderlands: The Handsome Collection',
#   'NBA 2K18: The Prelude',
#   'NBA 2K Online 2',
#   "Marvel's Midnight Suns",
#   'NBA 2K16',
#   'MLB Stickball',
#   'Battleborn',
#   "Sid Meier's Civilization VI",
#   'WWE SuperCard - Season 7',
#   'NHL 2K9',
#   'Ford Mustang: The Legend Lives',
#   'NBA 2K8',
#   'Borderlands: The Pre-Sequel!',
#   "Sid Meier's Civilization World",
#   'The Misadventures of P.B. Winterbottom',
#   'Major League Baseball 2K12',
#   'NBA 2K7',
#   'Don King Presents: Prizefighter',
#   "Dora's Puppy",
#   'Family Guy Video Game!',
#   'Prey',
#   'Dora the Explorer: Dora Saves the Snow Princess',
#   'Turd Birds',
#   'NHL 2K6',
#   'NBA 2K9',
#   'MyNBA 2K18',
#   'WWE 2K Battlegrounds',
#   'Sensei Wars',
#   'Serious Sam 2',
#   'XCOM: Enemy Unknown',
#   'BioShock Infinite',
#   'WWE 2K18',
#   'NBA 2K19: The Prelude',
#   'Major League Baseball 2K5: World Series Edition',
#   'NBA 2K Playgrounds 2',
#   'NHL 2K',
#   'Borderlands 3',
#   'Major League Baseball 2K8',
#   'The Da Vinci Code',
#   'Birthday Party Bash',
#   'Ringling Bros. and Barnum & Bailey: The Greatest Show on Earth',
#   'BioShock Remastered',
#   'Major League Baseball 2K6',
#   'NBA 2K17: The Prelude',
#   "Dora's Cooking Club",
#   'Major League Baseball 2K8: Fantasy All-Stars',
#   'NBA 2K18',
#   'MyNBA 2K15',
#   'Borderlands: Game of the Year Enhanced',
#   'NBA 2K20 Demo',
#   'NBA 2K All Stars',
#   "Sid Meier's Civilization IV",
#   'Borderlands Legends',
#   "Sid Meier's Ace Patrol",
#   'Nickelodeon Dance',
#   'MyNBA 2K20',
#   "Sid Meier's Civilization V",
#   'Conflict: Global Terror',
#   'New Carnival Games',
#   'MyNBA 2K21',
#   'NBA 2K Mobile - Season 2',
#   "Dora's Big Birthday Adventure",
#   'CivCity: Rome',
#   'Mafia II',
#   'Motocross Mania 3',
#   'The Darkness',
#   'BioShock: The Collection',
#   'Call of Cthulhu: Dark Corners of the Earth',
#   'The Backyardigans',
#   'College Hoops 2K6',
#   'NBA SuperCard',
#   'MLB Front Office Manager',
#   'Top Spin 2',
#   'Dora the Explorer: Dora Saves the Mermaids',
#   'Ringling Bros. and Barnum & Bailey: Circus Friends â\x80\x93 Asian Elephants',
#   'Axel & Pixel',
#   'Duke Nudem',
#   'MyNBA 2K16',
#   'XCOM: Chimera Squad',
#   'Ghost Rider',
#   '24: The Game',
#   'Duke Nukem Forever',
#   'Herd, Herd, Herd',
#   "Mega Bloks: Diego's Build and Rescue",
#   'Top Spin',
#   'BioShock',
#   'NHL 2K11',
#   'Major League Baseball 2K13',
#   'NBA 2K20',
#   'Borderlands: Legendary Collection',
#   'Dungeon Siege: Throne of Agony',
#   'Battleborn Tap',
#   'Major League Baseball 2K11',
#   'Ni Hao, Kai-Lan: Super Game Day',
#   'MyNBA 2K',
#   'NHL SuperCard 2K18',
#   'WWE 2K',
#   'MyNBA 2K17',
#   'Mafia III',
#   'GridBlock',
#   "Sid Meier's Civilization: Beyond Earth",
#   'BioShock Infinite: Industrial Revolution',
#   'BioShock 2',
#   "Let's Cheer!",
#   'Carnival Games: Wild West 3D',
#   'NBA 2K10',
#   'Haunted Hollow',
#   "Sid Meier's Civilization Revolution",
#   'The Elder Scrolls IV: Oblivion',
#   'Go, Diego, Go! Great Dinosaur Rescue',
#   'Carnival Games Volume II',
#   'WWE 2K19',
#   'Borderlands: The Handsome Collection â\x80\x93 Ultra HD',
#   'NHL 2K7',
#   'Spec Ops: The Line',
#   "Sid Meier's Civilization Revolution 2",
#   'BioShock 2 Remastered',
#   'WWE 2K16',
#   'Borderlands: Game of the Year Edition',
#   'WWE 2K14',
#   "Sid Meier's Civilization Online",
#   'Pro Baseball 2K',
#   'NBA 2K Mobile',
#   "Sid Meier's Pirates!",
#   'WWE SuperCard â\x80\x93 Season 2',
#   'Jade Empire: Special Edition',
#   'Carnival Games',
#   'WWE SuperCard â\x80\x93 Season 4',
#   'Deal or No Deal: Secret Vault Games',
#   "Tiny Tina's Wonderlands",
#   'Stronghold 2',
#   'Red Dead Revolver',
#   'Max Payne 2: The Fall of Max Payne',
#   'Red Dead Online',
#   'Manhunt 2',
#   'Grand Theft Auto: iFruit',
#   'State of Emergency',
#   'Thrasher: Skate and Destroy',
#   "Smuggler's Run: Warzones",
#   'Grand Theft Auto: The Ballad of Gay Tony',
#   'L.A. Noire: The VR Case Files',
#   'Grand Theft Auto: Mission Pack #1 - London 1969',
#   'Grand Theft Auto: Vice City',
#   'Grand Theft Auto 2',
#   'Manhunt',
#   'Grand Theft Auto V',
#   'Midnight Club: Los Angeles',
#   'Grand Theft Auto: Liberty City Stories',
#   'Grand Theft Auto: The Trilogy â\x80\x93 The Definitive Edition',
#   'Bully',
#   'The Italian Job',
#   'Grand Theft Auto Online',
#   'Evel Knievel',
#   'Earthworm Jim 3D',
#   'Monster Truck Madness 64',
#   'Grand Theft Auto: Mission Pack #2 - London 1961',
#   'Grand Theft Auto: San Andreas',
#   "Smuggler's Run",
#   'Grand Theft Auto IV',
#   'Red Dead Redemption 2',
#   'Grand Theft Auto',
#   "Smuggler's Run 2: Hostile Territory",
#   'Grand Theft Auto IV: The Lost and Damned',
#   'Grand Theft Auto: Chinatown Wars',
#   'Austin Powers: Welcome to My Underground Lair!',
#   'Midnight Club II',
#   'Midnight Club: Street Racing',
#   'Max Payne 3',
#   'Bully: Anniversary Edition',
#   'Red Dead Redemption',
#   'Wild Metal',
#   'Beaterator',
#   'Austin Powers: Oh, Behave!',
#   'Red Dead Redemption: Undead Nightmare',
#   'Grand Theft Auto: Vice City Stories',
#   'Grand Theft Auto III',
#   'Surfing H3O',
#   'Midnight Club 3: DUB Edition Remix',
#   'Bully: Scholarship Edition',
#   'Grand Theft Auto Advance',
#   'Midnight Club 3: DUB Edition',
#   'L.A. Noire',
#   'Oni',
#   'Rockstar Games presents Table Tennis',
#   'The Warriors',
#   'Max Payne']}

# %%
count = 0 
for value in game_names_1.values(): 
    count += len(value)

count
# Out:
# 938

# %% [markdown]
# # 3.2 Second approach - Manual selection of most popular games

# %%
game_names_2
# Out:
# {'EA': ['EA',
#   'Fifa',
#   'The Sims',
#   'Need for Speed',
#   'NFL',
#   'Apex',
#   'Battlefield',
#   'Bejeweled',
#   'Battlefront',
#   'NBA',
#   'Dragon Age',
#   'Titanfall',
#   'Dead Space'],
#  'TTWO': ['Take Two',
#   'NBA 2K',
#   'Battleborn',
#   'BioShock',
#   'Borderlands',
#   'Evolve',
#   'Mafia',
#   'Civilization',
#   'The Darkness',
#   'XCOM',
#   'WWE',
#   'GTA',
#   'Grand Theft Auto',
#   'Max Payne',
#   'Red Dead Redemption',
#   'RRD'],
#  'UBSFY': ['Ubisoft',
#   "Assasin's Creed",
#   'AC',
#   'Far Cry',
#   'Watch Dogs',
#   'Rainbow Six Siege',
#   'Wildlands',
#   'For Honor',
#   "Tom Clancy's",
#   'The Division'],
#  'ATVI': ['Blizzard',
#   'Starcraft',
#   'Warcraft',
#   'Overwatch',
#   'Diablo',
#   'World of Warcraft',
#   'Hearthstone',
#   'Heroes of the Storm']}

# %%
count = 0 
for value in game_names_2.values(): 
    count += len(value)

count
# Out:
# 47

# %% [markdown]
# # 4. Reddit text data scraping

# %%
reddit_dict['ATVI']
# Out:
#                   author                                               body  \
# 0             Bens_Dream  This doesn't sound like an issue with Blizzard...
# 1       jollysaintnick88  Is everyone forgetting that Blizzard just anno...
# 2              McManus26  Blizzard is the villain of the moment because ...
# 3                  frbap  While I hope it isn't true it wouldn't surpris...
# 4                  Zelun  I'm not saying this guy is lying or anything l...
# ...                  ...                                                ...
# 71564       MrManicMarty  I tried two games today, both ones I got on Ep...
# 71565            Sarasin  It is also easier to remember the misses becau...
# 71566      fkurgdmidtbrn  Change that to "most game players," lmao, it w...
# 71567     Smart_Ass_Dave  I have been AFK timer-ed only one time in my g...
# 71568  HopingForSomeHope  Hearthstone - yeah sure\n\nOW - I mean the gam...
#
#        created_utc  score       created            game_name
# 0       1547031922      1  1.547028e+09             Blizzard
# 1       1547034233      1  1.547031e+09             Blizzard
# 2       1547036254      1  1.547033e+09             Blizzard
# 3       1547037382      1  1.547034e+09             Blizzard
# 4       1547040421      1  1.547037e+09             Blizzard
# ...            ...    ...           ...                  ...
# 71564   1637534524      6  1.637531e+09  Heroes of the Storm
# 71565   1637379275      4  1.637376e+09  Heroes of the Storm
# 71566   1637279188      4  1.637276e+09  Heroes of the Storm
# 71567   1637267144      2  1.637264e+09  Heroes of the Storm
# 71568   1636501477      7  1.636498e+09  Heroes of the Storm
#
# [71569 rows x 6 columns]

# %%
reddit_dict['TTWO']
# Out:
#                    author                                               body  \
# 0          JustinHopewell  Neither does anyone's comments or wishes.\n\nS...
# 1              belgarionx  I don't care about Epic store since they can f...
# 2               cowbeef01  &gt;It plays tediously slowly, you can't skip ...
# 3       we_are_sex_bobomb  It’s also literally two different modes of pla...
# 4              gamelord12  One man's trash is another man's treasure.  I ...
# ...                   ...                                                ...
# 100183     -ImJustSaiyan-  They literally just put out Red Dead Redemptio...
# 100184     -ImJustSaiyan-  It's moreso the fact that games take longer to...
# 100185     A_Hard_Goodbye  I’ve refunded my copy and preordered Elden Rin...
# 100186        Kurtz_Angle  Watch GTA VI have a huge budget, incredibly de...
# 100187     -ImJustSaiyan-  It's moreso the fact that games take longer to...
#
#         created_utc  score       created            game_name
# 0        1547060916      1  1.547057e+09             Take Two
# 1        1547063267      1  1.547060e+09             Take Two
# 2        1546501359      1  1.546498e+09             Take Two
# 3        1546609292      1  1.546606e+09             Take Two
# 4        1546615505      1  1.546612e+09             Take Two
# ...             ...    ...           ...                  ...
# 100183   1636760170      1  1.636757e+09  Red Dead Redemption
# 100184   1636657299      1  1.636654e+09  Red Dead Redemption
# 100185   1636701444      1  1.636698e+09  Red Dead Redemption
# 100186   1636687405      1  1.636684e+09  Red Dead Redemption
# 100187   1636657299      1  1.636654e+09  Red Dead Redemption
#
# [100188 rows x 6 columns]

# %%
reddit_dict['UBSFY']
# Out:
#                   author                                               body  \
# 0          Marvellaneous  I have a theory that Ubisoft might've went wit...
# 1           duke82722009  Holy shit. Ubisoft jumping over to Epic's stor...
# 2          CrouchingPuma  This is huge. A gigantic publisher like Ubisof...
# 3              Senpaiuer  This is worse than most exclusives on consoles...
# 4                Jamcram  is this an exclusivity contract? ubisoft proba...
# ...                  ...                                                ...
# 71224            mak6453  Having health and showing health are different...
# 71225  Pulp_NonFiction44  Boxing is definitely making a return in the pu...
# 71226   MigratingPidgeon  To be honest, what pisses me off about the rec...
# 71227           DarkChen  &gt;Like ubisoft is really bad by this.\n\nI a...
# 71228               Zayl  Not even remotely true. That's just people on ...
#
#        created_utc  score       created     game_name
# 0       1547054214      1  1.547051e+09       Ubisoft
# 1       1547054348      1  1.547051e+09       Ubisoft
# 2       1547054777      1  1.547051e+09       Ubisoft
# 3       1547055149      1  1.547052e+09       Ubisoft
# 4       1547055198      1  1.547052e+09       Ubisoft
# ...            ...    ...           ...           ...
# 71224   1636677504     -3  1.636674e+09  The Division
# 71225   1636564763     34  1.636561e+09  The Division
# 71226   1636660920      7  1.636657e+09  The Division
# 71227   1636565566      5  1.636562e+09  The Division
# 71228   1636503808      2  1.636500e+09  The Division
#
# [71229 rows x 6 columns]

# %% [markdown]
# # 5. Next steps:
#     - Perform sentiment analysis on reddit dataset using BERT model
#     - Add Covid measurment
#     - Add more Technical Indicators
#     - Explore GAN
